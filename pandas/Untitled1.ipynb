# %%
import pandas as pd

# %%
#load the csv file with no headers
data = pd.read_csv('../data/titanic_no_header.csv',header=None)
#get the first 5 rows
data.head()
# Out:
#    0   1   2                                                  3       4   \
# 0   1   0   3                            Braund, Mr. Owen Harris    male
# 1   2   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2   3   1   3                             Heikkinen, Miss. Laina  female
# 3   4   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4   5   0   3                           Allen, Mr. William Henry    male
#
#      5   6   7                 8        9     10 11
# 0  22.0   1   0         A/5 21171   7.2500   NaN  S
# 1  38.0   1   0          PC 17599  71.2833   C85  C
# 2  26.0   0   0  STON/O2. 3101282   7.9250   NaN  S
# 3  35.0   1   0            113803  53.1000  C123  S
# 4  35.0   0   0            373450   8.0500   NaN  S

# %%
#load the csv file with no headers and give column names as 
col_names = ['a','b','c','d','e','f','g','h','i','j','k']
data = pd.read_csv('../data/titanic_no_header.csv',header=None,names =col_names)
#get the first 5 rows
data.head()
# Out:
#    a  b                                                  c       d     e  f  \
# 1  0  3                            Braund, Mr. Owen Harris    male  22.0  1
# 2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  1
# 3  1  3                             Heikkinen, Miss. Laina  female  26.0  0
# 4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  1
# 5  0  3                           Allen, Mr. William Henry    male  35.0  0
#
#    g                 h        i     j  k
# 1  0         A/5 21171   7.2500   NaN  S
# 2  0          PC 17599  71.2833   C85  C
# 3  0  STON/O2. 3101282   7.9250   NaN  S
# 4  0            113803  53.1000  C123  S
# 5  0            373450   8.0500   NaN  S

# %%
#load the csv file with headers and override the headers with ours
col_names = ['a','b','c','d','e','f','g','h','i','j','k']
data = pd.read_csv('../data/titanic.csv',header=0,names =col_names)
#get the first 5 rows
data.head()
# Out:
#    a  b                                                  c       d     e  f  \
# 1  0  3                            Braund, Mr. Owen Harris    male  22.0  1
# 2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  1
# 3  1  3                             Heikkinen, Miss. Laina  female  26.0  0
# 4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  1
# 5  0  3                           Allen, Mr. William Henry    male  35.0  0
#
#    g                 h        i     j  k
# 1  0         A/5 21171   7.2500   NaN  S
# 2  0          PC 17599  71.2833   C85  C
# 3  0  STON/O2. 3101282   7.9250   NaN  S
# 4  0            113803  53.1000  C123  S
# 5  0            373450   8.0500   NaN  S
